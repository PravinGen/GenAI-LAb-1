# %%
import sys
import os

sys.path.insert(0, os.path.abspath(".."))

print("✅ Path added")
# Out:
# ✅ Path added

# %%
from dotenv import load_dotenv
import os

load_dotenv()
print("API:", os.getenv("GOOGLE_API_KEY"))
# Out:
# API: AIzaSyDFr3k6LrrcelmW99Li6OvWmhQA_09cUqk

# %%
from langgraph.graph import StateGraph
from langgraph.graph.message import MessagesState
from langchain_core.messages import HumanMessage

from llm import get_llm

# %%
llm = get_llm("gemini-flash-lite")

# %%
def ask_llm(state: MessagesState):
    messages = state["messages"]
    response = llm.invoke(messages)
    return {"messages": messages + [response]}

# %%
builder = StateGraph(MessagesState)

builder.add_node("ask_llm", ask_llm)
builder.set_entry_point("ask_llm")
builder.set_finish_point("ask_llm")

graph = builder.compile()

# %%
result = graph.invoke({
    "messages": [
        HumanMessage(content="Explain Agentic AI")
    ]
})

print(result["messages"][-1].content)
# Out:
# **Agentic AI** refers to Artificial Intelligence systems designed to act as autonomous "agents" that can perceive their environment, reason about it, plan actions, and execute those actions to achieve a specific goal, often without constant human intervention for every step.
#
# Think of it as moving beyond a simple chatbot that just responds to prompts, to an AI that can take a high-level instruction and proactively work towards fulfilling it, breaking down the task into smaller steps, using tools, and adapting its approach as needed.
#
# ### Core Characteristics of Agentic AI:
#
# 1.  **Goal-Oriented:** The AI is given a high-level objective (e.g., "Plan a trip to Paris for next month," "Research the latest trends in renewable energy," "Develop a simple web application").
# 2.  **Autonomy:** Once given a goal, the agent operates independently, making decisions and taking actions without requiring explicit human approval for each micro-step.
# 3.  **Perception:** It can "observe" its environment, which might be digital (reading web pages, API responses, file contents) or physical (using sensors in robotics).
# 4.  **Reasoning & Planning:** It can break down complex goals into smaller, manageable sub-tasks, determine the logical sequence of actions, and strategize how to achieve each sub-task.
# 5.  **Action & Execution:** It can perform actions in its environment. This often involves using various "tools" (e.g., web browsers, APIs, code interpreters, email clients, file systems).
# 6.  **Memory & State Management:** It maintains a context of its past actions, observations, and the current state of its environment to inform future decisions. This allows for multi-step processes and learning.
# 7.  **Adaptability & Learning (often):** It can evaluate the outcomes of its actions, learn from failures or unexpected results, and adjust its plans or strategies accordingly.
# 8.  **Tool Use:** A crucial aspect is the ability to integrate and use external tools and services to extend its capabilities beyond its core AI model.
#
# ### How Agentic AI Works (Simplified Loop):
#
# 1.  **Receive Goal:** User provides a high-level objective.
# 2.  **Plan:** The AI (often powered by a Large Language Model - LLM) analyzes the goal and generates a plan, breaking it into sub-tasks.
# 3.  **Act:** It selects the most appropriate action for the current sub-task. This might involve:
#     *   Searching the internet.
#     *   Calling an API (e.g., a calendar API, a weather API).
#     *   Writing and executing code.
#     *   Sending an email.
#     *   Interacting with a database.
# 4.  **Observe:** It monitors the outcome of its action.
# 5.  **Reflect/Evaluate:** It assesses whether the action was successful, if the plan needs adjustment, or if the goal has been achieved.
# 6.  **Loop:** It repeats steps 2-5 until the goal is met, deemed impossible, or a human intervenes.
#
# ### Examples of Agentic AI in Action:
#
# *   **Personal Assistants:** An AI that can not only answer questions but also book flights, manage your calendar, send emails, and order groceries based on your preferences.
# *   **Software Development Agents:** An AI that can take a feature request, write the code, debug it, run tests, and even deploy it to a staging environment.
# *   **Research Agents:** An AI that can be tasked with "Find all scientific papers on CRISPR gene editing published in the last year and summarize their key findings," then autonomously search databases, read papers, and synthesize information.
# *   **Customer Service Agents:** Beyond simple chatbots, an agentic AI could diagnose complex technical issues, access customer records, troubleshoot problems, and even initiate refunds or service calls.
# *   **Robotics:** A robot that can navigate a warehouse, identify specific items, pick them up, and place them in a designated area, adapting to obstacles or changes in inventory.
#
# ### Why is Agentic AI a Significant Development?
#
# Agentic AI represents a shift from AI as a reactive tool to AI as a proactive partner. It leverages the reasoning capabilities of modern AI models (especially LLMs) and combines them with the ability to interact with the real world (digital or physical). This unlocks the potential for much higher levels of automation, problem-solving, and personalized assistance across various domains.
#
# However, it also introduces new challenges related to safety, control, transparency, and the potential for unintended consequences, making robust design and oversight crucial.
